# %%
# !git clone https://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@github.com/devangguptaa/llava-pmc-vqa.git
# Out:
# Cloning into 'llava-pmc-vqa'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 33 (delta 13), reused 26 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 15.54 MiB | 4.65 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# %cd llava-pmc-vqa
# !pwd
# !git submodule update --init --recursive
# Out:
# /content/llava-pmc-vqa
# /content/llava-pmc-vqa
# Submodule 'LLaVA' (https://github.com/haotian-liu/LLaVA.git) registered for path 'LLaVA'
# Cloning into '/content/llava-pmc-vqa/LLaVA'...
# Submodule path 'LLaVA': checked out 'c121f0432da27facab705978f83c4ada465e46fd'

# %%
# !pip install -e /content/llava-pmc-vqa/LLaVA --no-deps
# Out:
# Obtaining file:///content/llava-pmc-vqa/LLaVA
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for llava (pyproject.toml) ... done
#   Created wheel for llava: filename=llava-1.2.2.post1-0.editable-py3-none-any.whl size=17902 sha256=034cc67ed90ef82bb84a74da371dac09212ae1f01829868bef1b6869434f881a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8p5tpfp6/wheels/fc/5b/80/56035d3e94b4e57ef74df4b4e79600014e5cc8bda25e30d095
# Successfully built llava
# ...

# %%
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 44.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.2.2.post1 requires einops-exts==0.0.4, which is not installed.
# llava 1.2.2.post1 requires markdown2[all], which is not installed.
# llava 1.2.2.post1 requires shortuuid, which is not installed.
# llava 1.2.2.post1 requires accelerate==0.21.0, but you have accelerate 1.12.0 which is incompatible.
# llava 1.2.2.post1 requires einops==0.6.1, but you have einops 0.8.1 which is incompatible.
# llava 1.2.2.post1 requires gradio==4.16.0, but you have gradio 5.50.0 which is incompatible.
# llava 1.2.2.post1 requires gradio_client==0.8.1, but you have gradio-client 1.14.0 which is incompatible.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# ...

# %%
# !pip install sentencepiece==0.1.99
# !pip install "transformers==4.37.2" "peft==0.10.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 56.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sentencepiece: filename=sentencepiece-0.1.99-cp312-cp312-linux_x86_64.whl size=1266901 sha256=4c572866cb1f3bbe1f16c172b6205800e1c85e174ec70684a289c2994c0890bf
#   Stored in directory: /root/.cache/pip/wheels/e0/8c/e0/65e33b1f4b8462dfc537a0cac02e5c03e1207564c300e4bde5
# Successfully built sentencepiece
# ...
#   Attempting uninstall: sentencepiece
#     Found existing installation: sentencepiece 0.2.1
#     Uninstalling sentencepiece-0.2.1:
#       Successfully uninstalled sentencepiece-0.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.2.2.post1 requires einops-exts==0.0.4, which is not installed.
# llava 1.2.2.post1 requires markdown2[all], which is not installed.
# ...

# %%
# !pip install accelerate deepspeed einops-exts einops gradio gradio_client httpx markdown numpy scikit-learn shortuuid timm tokenizers torchvision wandb wavedrom
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 19.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 7.1 MB/s eta 0:00:00
# ...
#   Created wheel for deepspeed: filename=deepspeed-0.18.2-py3-none-any.whl size=1763305 sha256=4a82e45fabd58d2e5e6ee0fb23447679e80a319a441a27c5eff7903bd0548962
#   Stored in directory: /root/.cache/pip/wheels/69/ad/2e/e03d4739ddc0417efd8a120c2b9e784005aa226037e558c163
# ...
#   Created wheel for wavedrom: filename=wavedrom-2.0.3.post3-py2.py3-none-any.whl size=30142 sha256=9d1ea3078378ca7d548a289ef5619bf0c7a30a0a88a14eb1e60202cfe0ca15c7
# ...

# %%
# !pip install Pygments

# %%
# !apt install git-lfs
# !git lfs install
# !pwd
# %cd /content

! GIT_LFS_SKIP_SMUDGE=1 git clone https://huggingface.co/datasets/RadGenome/PMC-VQA
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Updated git hooks.
# Git LFS initialized.
# /content/llava-pmc-vqa
# /content
# Cloning into 'PMC-VQA'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 57 (delta 1), reused 0 (delta 0), pack-reused 50 (from 1)
# Unpacking objects: 100% (57/57), 155.41 KiB | 3.24 MiB/s, done.

# %%
# %cd /content/PMC-VQA/
! vim images.zip
# ! git lfs pull --include="images.zip"
# Out:
# /content/PMC-VQA
# 7[>4;2m="images.zip" 3L, 136B▽  Pzz\[0%m           [>cversion https://git-lfs.github.com/spec/v1
# ...

# %%
# !pwd
# Out:
# /content/PMC-VQA

# %%
# !GIT_TRACE=1 GIT_CURL_VERBOSE=1 git lfs pull --include="images.zip"
# Out:
# 17:04:28.398817 git.c:742               trace: exec: git-lfs pull --include=images.zip
# 17:04:28.398855 run-command.c:668       trace: run_command: git-lfs pull --include=images.zip
# 17:04:28.402424 trace git-lfs: exec: git 'version'
# 17:04:28.404111 trace git-lfs: exec: git '-c' 'filter.lfs.smudge=' '-c' 'filter.lfs.clean=' '-c' 'filter.lfs.process=' '-c' 'filter.lfs.required=false' 'rev-parse' '--git-dir' '--show-toplevel'
# 17:04:28.405524 trace git-lfs: exec: git 'rev-parse' '--is-bare-repository'
# 17:04:28.406861 trace git-lfs: exec: git 'config' '--includes' '--local' 'lfs.repositoryformatversion'
# 17:04:28.408142 trace git-lfs: exec: git 'config' '--includes' '-l'
# 17:04:28.409466 trace git-lfs: exec: git 'rev-parse' '--is-bare-repository'
# 17:04:28.410774 trace git-lfs: exec: git 'config' '--includes' '-l' '--blob' ':.lfsconfig'
# 17:04:28.412214 trace git-lfs: exec: git 'config' '--includes' '-l' '--blob' 'HEAD:.lfsconfig'
# ...

# %%
# !mv images.zip /content/images.zip

# %%
# %cd /content/
! rm -rf PMC-VQA/
# Out:
# /content

# %%
# !unzip images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/PMC7874794_j_biol-2019-0035_fig_006.jpg
#   inflating: images/PMC6148031_Fig1.jpg
#   inflating: images/PMC9378323_Fig1.jpg
#   inflating: images/PMC2396155_F2.jpg
#   inflating: images/PMC4093318_F3.jpg
#   inflating: images/PMC8569400_fig0002.jpg
#   inflating: images/PMC8612748_FIG1.jpg
#   inflating: images/PMC4049769_f1-ol-07-06-1847.jpg
#   inflating: images/PMC2734526_F1.jpg
#   inflating: images/PMC3498183_pone-0050122-g002.jpg
#   inflating: images/PMC8908603_Fig6.jpg
#   inflating: images/PMC8363778_FIG3.jpg
#   inflating: images/PMC5310572_Fig10.jpg
#   inflating: images/PMC8501738_Fig2.jpg
#   inflating: images/PMC4956622_Fig5.jpg
#   inflating: images/PMC3585969_pone-0057583-g002.jpg
#   inflating: images/PMC7570024_jcdd-07-00030-f019.jpg
#   inflating: images/PMC6477770_fig3-1756286419840593.jpg
#   inflating: images/PMC4786376_FIG1.jpg
#   inflating: images/PMC8917295_f0010.jpg
# ...

# %%
! vim /content/llava-pmc-vqa/LLaVA/scripts/finetune_lora.sh
# Out:
# <pmc-vqa/LLaVA/scripts/finetune_lora.sh" 49L, 1672B▽  Pzz\[0%m           [>c#!/bin/bash# IMPORTANT: this is the training script for the original LLaVA, NOT FOR LLaVA VV1.5!
#
# # Uncomment and set the following variables correspondingly to run this script:
#
# ################## VICUNA ##################
# # PROMPT_VERSION=v1
# # MODEL_VERSION="vicuna-v1-3-7b"
# ################## VICUNA ##################
#
# ################## LLaMA-2 ##################
# # PROMPT_VERSION="llava_llama_2"
# # MODEL_VERSION="llama-2-7b-chat"
# ################## LLaMA-2 ##################
#
# deepspeed llava/train/train_mem.py \
#     --deepspeed ./scripts/zero2.json \
#     --lora_enable True \
#     --model_name_or_path ./checkpoints/$MODEL_VERSION \
#     --version $PROMPT_VERSION \
#     --data_path ./playground/data/llava_instruct_80k.json \1,1Top>[>4;m8Vim: Caught deadly signal TERM
# Vim: Finished.
#
# ^C

# %%
! rm -rf images.zip

# %%
# !pip install accelerate==0.21.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 12.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.12.0
#     Uninstalling accelerate-1.12.0:
#       Successfully uninstalled accelerate-1.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.2.2.post1 requires markdown2[all], which is not installed.
# llava 1.2.2.post1 requires einops==0.6.1, but you have einops 0.8.1 which is incompatible.
# llava 1.2.2.post1 requires gradio==4.16.0, but you have gradio 5.50.0 which is incompatible.
# llava 1.2.2.post1 requires gradio_client==0.8.1, but you have gradio-client 1.14.0 which is incompatible.
# llava 1.2.2.post1 requires httpx==0.24.0, but you have httpx 0.28.1 which is incompatible.
# ...

# %%
# !pip install "pydantic>2"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 102.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.24
#     Uninstalling pydantic-1.10.24:
#       Successfully uninstalled pydantic-1.10.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.2.2.post1 requires markdown2[all], which is not installed.
# llava 1.2.2.post1 requires einops==0.6.1, but you have einops 0.8.1 which is incompatible.
# ...

# %%
import os
os.environ['WANDB_API_KEY'] = '21c42c71e179105157ba85a6c2e8633546600aed'

# %%
import sys
import os

# --- FIX: Add LLaVA directory to Python Path ---
# This tells Python to look inside your LLaVA folder for imports
sys.path.append("/content/llava-pmc-vqa/LLaVA")
# -----------------------------------------------

import torch
from peft import PeftModel
from transformers import AutoTokenizer

# Now this import will work
from llava.model.language_model.llava_llama import LlavaLlamaForCausalLM

# --- CONFIGURATION ---
BASE_MODEL_PATH = "liuhaotian/llava-v1.5-7b"
# Update this to your actual checkpoint path
ADAPTER_PATH = "/content/llava-v1.5-7b-task-lora"
SAVE_PATH = "/content/llava-v1.5-7b-merged"
# ---------------------

print(f"1. Loading base model: {BASE_MODEL_PATH}")
model = LlavaLlamaForCausalLM.from_pretrained(
    BASE_MODEL_PATH,
    torch_dtype=torch.float16,
    low_cpu_mem_usage=True,
    device_map="auto"
)

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL_PATH, use_fast=False)

print(f"2. Loading LoRA adapter: {ADAPTER_PATH}")
# Resize token embeddings first just in case new tokens were added
model.resize_token_embeddings(len(tokenizer))

# Load the adapter
model = PeftModel.from_pretrained(model, ADAPTER_PATH)

print("3. Merging weights...")
model = model.merge_and_unload()

print(f"4. Saving full model to: {SAVE_PATH}")
model.save_pretrained(SAVE_PATH)
tokenizer.save_pretrained(SAVE_PATH)

print("Done! Model merged successfully.")
# Out:
# 1. Loading base model: liuhaotian/llava-v1.5-7b
# You are using a model of type llava to instantiate a model of type llava_llama. This is not supported for all configurations of models and can yield errors.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# 2. Loading LoRA adapter: /content/llava-v1.5-7b-task-lora
# 3. Merging weights...
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 4096}
# 4. Saving full model to: /content/llava-v1.5-7b-merged
# Done! Model merged successfully.

# %%
#!/bin/bash

# !deepspeed /content/llava-pmc-vqa/LLaVA/llava/train/train_mem.py \
    --lora_enable True  --lora_r 128  --lora_alpha 256 \
    --mm_projector_lr 2e-5 \
    --deepspeed /content/llava-pmc-vqa/LLaVA/scripts/zero2.json \
    --model_name_or_path liuhaotian/llava-v1.5-7b \
    --version v1 \
    --data_path /content/llava-pmc-vqa/pmc_vqa_train_llava.json \
    --eval_data_path /content/llava-pmc-vqa/pmc_vqa_val_llava.json \
    --evaluation_strategy "steps" \
    --eval_steps 1000 \
    --image_folder /content/images \
    --vision_tower openai/clip-vit-large-patch14-336 \
    --mm_projector_type mlp2x_gelu \
    --mm_vision_select_layer -2 \
    --mm_use_im_start_end False \
    --mm_use_im_patch_token False \
    --image_aspect_ratio pad \
    --group_by_modality_length True \
    --bf16 True \
    --output_dir /content/llava-v1.5-7b-task-lora-epoch2-lora \
    --num_train_epochs 1 \
    --per_device_train_batch_size 42 \
    --per_device_eval_batch_size 42 \
    --gradient_accumulation_steps 1 \
    --save_strategy "steps" \
    --save_steps 1000 \
    --save_total_limit 3 \
    --learning_rate 2e-5 \
    --weight_decay 0. \
    --warmup_ratio 0.03 \
    --lr_scheduler_type "cosine" \
    --logging_steps 10 \
    --tf32 True \
    --model_max_length 2048 \
    --gradient_checkpointing True \
    --dataloader_num_workers 4 \
    --lazy_preprocess True \
    --report_to wandb \
    --lora_weight_path /content/llava-v1.5-7b-task-lora
# Out:
# 2025-12-02 18:26:20.433048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764699980.455410   26272 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764699980.462157   26272 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764699980.479383   26272 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
! cp -r /content/llava-v1.5-7b-task-lora-epoch2-lora/ /content/llava-v1.5-7b-task-lora-epoch2-lora-backup/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# Out:
# /content

# %%
# !rm -rf /content/llava-v1.5-7b-merged/

# %%
# !cp -r /content/llava-v1.5-7b-task-lora-epoch2-lora/ \
      "/content/drive/MyDrive/llava-v1.5-7b-task-lora-epoch2"

# !cp -r "/content/drive/MyDrive/llava-v1.5-7b-task-lora" \
#       "/content/llava-v1.5-7b-task-lora"

# ! cp -r /content/llava-v1.5-7b-task-lora \
# "/content/checkpoints/llava-v1.5-7b-task-lora"

# %%
! ls -r -lh /content/drive/MyDrive/llava-v1.5-7b-task-lora-epoch2

# !ls -r -lh /content/llava-v1.5-7b-task-lora-epoch2-lora
# Out:
# total 651M
# -rw------- 1 root root  41K Dec  3 04:52 trainer_state.json
# -rw------- 1 root root 5.0K Dec  3 04:52 README.md
# -rw------- 1 root root  41M Dec  3 04:52 non_lora_trainables.bin
# -rw------- 1 root root 1.4K Dec  3 04:52 config.json
# drwx------ 3 root root 4.0K Dec  3 04:52 checkpoint-3000
# drwx------ 3 root root 4.0K Dec  3 04:52 checkpoint-2000
# drwx------ 3 root root 4.0K Dec  3 04:52 checkpoint-1000
# -rw------- 1 root root 611M Dec  3 04:52 adapter_model.safetensors
# -rw------- 1 root root  729 Dec  3 04:52 adapter_config.json
# total 651M
# -rw-r--r-- 1 root root  41K Dec  3 04:48 trainer_state.json
# -rw-r--r-- 1 root root 5.0K Dec  3 04:48 README.md
# -rw-r--r-- 1 root root  41M Dec  3 04:48 non_lora_trainables.bin
# -rw-r--r-- 1 root root 1.4K Dec  3 04:48 config.json
# drwxr-xr-x 3 root root 4.0K Dec  3 03:55 checkpoint-3000
# drwxr-xr-x 3 root root 4.0K Dec  3 00:45 checkpoint-2000
# drwxr-xr-x 3 root root 4.0K Dec  2 21:36 checkpoint-1000
# ...

# %%
# !zip -r /content/llava-v1.5-7b-task-lora-epoch2.zip /content/llava-v1.5-7b-task-lora-epoch2-lora/
# Out:
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/ (stored 0%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/non_lora_trainables.bin (deflated 21%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/trainer_state.json (deflated 83%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/config.json (deflated 57%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/checkpoint-2000/ (stored 0%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/checkpoint-2000/tokenizer_config.json (deflated 69%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/checkpoint-2000/training_args.bin (deflated 52%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/checkpoint-2000/global_step2000/ (stored 0%)
#   adding: content/llava-v1.5-7b-task-lora-epoch2-lora/checkpoint-2000/global_step2000/bf16_zero_pp_rank_0_mp_rank_00_optim_states.pt
#
#
# zip error: Interrupted (aborting)

# %%
import os
import json
from PIL import Image

import torch
from torch.utils.data import Dataset, DataLoader

from llava.model.builder import load_pretrained_model
from llava.mm_utils import tokenizer_image_token
from llava.constants import IMAGE_TOKEN_INDEX

test_json = "/content/llava-pmc-vqa/pmc_vqa_test_llava.json"
image_folder = "/content/images"

model_path = "/content/llava-v1.5-7b-task-lora-epoch2-lora-backup"
tokenizer, model, image_processor, context_len = load_pretrained_model(
    model_name="llava-v1.5-7b-lora_epoch1",
    model_path=model_path,
    model_base="liuhaotian/llava-v1.5-7b",
    load_8bit=False,
    load_4bit=False,
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


class PMCVQADataset(Dataset):
    def __init__(self, json_path, image_root):
        self.items = json.load(open(json_path))
        self.image_root = image_root

    def __len__(self):
        return len(self.items)

    def __getitem__(self, idx):
        item = self.items[idx]

        img_path = os.path.join(self.image_root, item["image"])
        image = Image.open(img_path).convert("RGB")

        # conversation format: [0]=system, [1]=human (\nQ), [2]=gpt
        question = item["conversations"][0]["value"]
        gt_answer = item["conversations"][1]["value"]

        # You can include system prompt in the text if you want:
        # prompt = system_prompt + "\n" + question
        prompt = question

        return {
            "id": item.get("id", idx),
            "image": image,
            "prompt": prompt,
            "gt_answer": gt_answer,
            "raw_item": item,
        }


def collate_fn(batch):
    # images to tensor
    images = [b["image"] for b in batch]
    images = image_processor.preprocess(images, return_tensors="pt")["pixel_values"].half()

    prompts = [b["prompt"] for b in batch]
    input_ids = [tokenizer_image_token(p, tokenizer, return_tensors="pt") for p in prompts]
    # pad to same length
    input_ids = torch.nn.utils.rnn.pad_sequence(
        input_ids, batch_first=True, padding_value=tokenizer.pad_token_id
    )

    return {
        "ids": [b["id"] for b in batch],
        "images": images,
        "input_ids": input_ids,
        "gt_answers": [b["gt_answer"] for b in batch],
        "raw_items": [b["raw_item"] for b in batch],
    }


dataset = PMCVQADataset(test_json, image_folder)
loader = DataLoader(
    dataset,
    batch_size=42,              # tune this based on VRAM
    shuffle=True,
    num_workers=6,
    collate_fn=collate_fn,
)

results = []

model.eval()
with torch.no_grad():
    ctr  = 1
    for batch in loader:
        images = batch["images"].to(device)
        input_ids = batch["input_ids"].to(device)

        output_ids = model.generate(
            input_ids,
            images=images,
            max_new_tokens=20,
            min_new_tokens=5,
            do_sample=False,
            temperature=0.0,
        )

        for i, out in enumerate(output_ids):
            # pred = tokenizer.decode(out, skip_special_tokens=True).strip()
            raw_pred = tokenizer.decode(out, skip_special_tokens=True).strip()

            # Get the original human message (with \n)
            human_msg = batch["raw_items"][i]["conversations"][0]["value"]

            # Strip off the  part to get just the text question
            # e.g. "\nWhat muscle is this?" -> "What muscle is this?"
            if "\n" in human_msg:
                _, plain_q = human_msg.split("\n", 1)
            else:
                plain_q = human_msg
            plain_q = plain_q.strip()

            pred = raw_pred

            # 1) If prediction literally starts with the question text, strip it
            if plain_q and pred.lower().startswith(plain_q.lower()):
                pred = pred[len(plain_q):].strip()

            # 2) If there's still a question mark early on, drop everything up to '?'
            #    (handles cases like "What muscle is this? Vastus lateralis")
            qpos = pred.find("?")
            if qpos != -1 and qpos < 80:   # 80 is just a heuristic cutoff
                pred = pred[qpos+1:].strip()

            # 3) Take only the first line
            # pred = pred.split("\n")[0].strip()

            # # 4) Optional: strip "Answer:" prefix
            # if pred.lower().startswith("answer:"):
            #     pred = pred.split(":", 1)[1].strip()

            results.append({
                "id": batch["ids"][i],
                "image": batch["raw_items"][i]["image"],
                "question": batch["raw_items"][i]["conversations"][0]["value"],
                "prediction": pred,
                "gt_answer": batch["gt_answers"][i].strip(),
            })
            print(f"SAMPLE{ctr} prediction", pred, "gt:", batch["gt_answers"][i].strip())
            ctr  += 1

out_path = "/content/pmc_vqa_llava_epoch2_predictions.json"
with open(out_path, "w") as f:
    json.dump(results, f, indent=2)

print(f"Saved predictions to {out_path}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading LLaVA from base model...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading additional LLaVA weights...
# Loading LoRA weights...
# Merging LoRA weights...
# Model is loaded...
# /usr/local/lib/python3.12/dist-packages/transformers/generation/configuration_utils.py:392: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# SAMPLE44962 prediction “​“​“​“​“​“​“​“​“​“​ gt: octopus's appearance
# SAMPLE44963 prediction  gt: mri
# ...

# %%
# !cp -r /content/pmc_vqa_llava_epoch2_predictions.json /content/drive/MyDrive/pmc_vqa_llava_epoch2_predictions.json
